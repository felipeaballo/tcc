# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
from hygese import AlgorithmParameters, Solver

# %% [markdown]
# # Cenário 01

# %% [markdown]
# ## Pegando o DF e Tratando os dados

# %%
df01 = pd.read_excel('matriz_cenarios.xlsx', sheet_name='C_01')

df01 = df01.set_index('Unnamed: 0')

df01 = df01.replace('-', 0)

matriz01 = df01.to_numpy()
# Out:
# C:\Users\Felipe\AppData\Local\Temp\ipykernel_94972\1811228510.py:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df01 = df01.replace('-', 0)

# %% [markdown]
# ## Resolvendo para o cenário 01

# %%
data = dict()
data['distance_matrix'] = matriz01
data['num_vehicles'] = 1
data['depot'] = 0
data['demands'] = [1]*58
data['demands'][0] = 0
data['vehicle_capacity'] = 150  # different from OR-Tools: homogeneous capacity
data['service_times'] = np.zeros(len(data['demands']))

# Solver initialization
ap = AlgorithmParameters(timeLimit=3.2)  # seconds
hgs_solver = Solver(parameters=ap, verbose=True)

# Solve
result_01 = hgs_solver.solve_cvrp(data)
print("Custo: ", result_01.cost)
print("Rota: ", result_01.routes)
# Out:
# Custo:  144966.90000000002
# Rota:  [[35, 47, 42, 30, 50, 28, 22, 24, 29, 32, 25, 27, 31, 26, 19, 21, 15, 16, 23, 2, 3, 1, 8, 4, 55, 6, 56, 49, 10, 12, 9, 5, 7, 11, 52, 38, 34, 33, 40, 18, 13, 14, 17, 57, 20, 39, 48, 41, 43, 44, 46, 45, 51, 36, 37, 54, 53]]

# %% [markdown]
# # Cenário 02

# %%
df02 = pd.read_excel('matriz_cenarios.xlsx', sheet_name='C_02')

df02 = df02.set_index('Unnamed: 0')

df02 = df02.replace('-', 0)

matriz02 = df02.to_numpy()

## Dados

data = dict()
data['distance_matrix'] = matriz02
data['num_vehicles'] = 1
data['depot'] = 0
data['demands'] = [1]*58
data['demands'][0] = 0
data['vehicle_capacity'] = 150  # different from OR-Tools: homogeneous capacity
data['service_times'] = np.zeros(len(data['demands']))

# Solver initialization
ap = AlgorithmParameters(timeLimit=3.2)  # seconds
hgs_solver = Solver(parameters=ap, verbose=True)

# Solve
result_02 = hgs_solver.solve_cvrp(data)
print("Custo: ", result_02.cost)
print("Rota: ", result_02.routes)
# Out:
# C:\Users\Felipe\AppData\Local\Temp\ipykernel_94972\2952822661.py:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df02 = df02.replace('-', 0)
# Custo:  146347.9
# Rota:  [[11, 52, 38, 34, 33, 40, 18, 13, 14, 17, 57, 20, 39, 48, 41, 43, 44, 46, 45, 51, 36, 37, 54, 53, 35, 47, 42, 30, 50, 28, 22, 24, 29, 32, 25, 27, 31, 26, 19, 21, 15, 16, 23, 2, 3, 1, 8, 4, 55, 6, 56, 49, 10, 12, 9, 5, 7]]

# %% [markdown]
# # Cenário 03

# %%
df03 = pd.read_excel('matriz_cenarios.xlsx', sheet_name='C_03')

df03 = df03.set_index('Unnamed: 0')

df03 = df03.replace('-', 0)

matriz03 = df03.to_numpy()

## Dados

data = dict()
data['distance_matrix'] = matriz03
data['num_vehicles'] = 1
data['depot'] = 0
data['demands'] = [1]*58
data['demands'][0] = 0
data['vehicle_capacity'] = 150  # different from OR-Tools: homogeneous capacity
data['service_times'] = np.zeros(len(data['demands']))

# Solver initialization
ap = AlgorithmParameters(timeLimit=3.2)  # seconds
hgs_solver = Solver(parameters=ap, verbose=True)

# Solve
result_03 = hgs_solver.solve_cvrp(data)
print("Custo: ", result_03.cost)
print("Rota: ", result_03.routes)
# Out:
# C:\Users\Felipe\AppData\Local\Temp\ipykernel_94972\2087044385.py:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df03 = df03.replace('-', 0)
# Custo:  144891.59999999998
# Rota:  [[27, 31, 25, 24, 22, 29, 32, 26, 19, 21, 15, 16, 23, 2, 3, 1, 8, 4, 55, 6, 56, 49, 10, 12, 9, 5, 7, 11, 52, 38, 34, 33, 40, 18, 13, 14, 17, 57, 20, 39, 48, 41, 42, 30, 28, 50, 35, 47, 54, 53, 37, 36, 51, 45, 46, 44, 43]]

# %% [markdown]
# # Cenário 04

# %%
df04 = pd.read_excel('matriz_cenarios.xlsx', sheet_name='C_04')

df04 = df04.set_index('Unnamed: 0')

df04 = df04.replace('-', 0)

matriz04 = df04.to_numpy()

## Dados

data = dict()
data['distance_matrix'] = matriz04
data['num_vehicles'] = 1
data['depot'] = 0
data['demands'] = [1]*58
data['demands'][0] = 0
data['vehicle_capacity'] = 150  # different from OR-Tools: homogeneous capacity
data['service_times'] = np.zeros(len(data['demands']))

# Solver initialization
ap = AlgorithmParameters(timeLimit=3.2)  # seconds
hgs_solver = Solver(parameters=ap, verbose=True)

# Solve
result_04 = hgs_solver.solve_cvrp(data)
print("Custo: ", result_04.cost)
print("Rota: ", result_04.routes)
# Out:
# C:\Users\Felipe\AppData\Local\Temp\ipykernel_94972\888456568.py:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df04 = df04.replace('-', 0)
# Custo:  144636.9
# Rota:  [[57, 20, 39, 48, 41, 43, 44, 46, 45, 51, 36, 37, 54, 53, 35, 47, 42, 30, 50, 28, 22, 24, 29, 32, 25, 27, 31, 26, 19, 21, 15, 16, 23, 2, 3, 1, 8, 4, 55, 6, 56, 49, 10, 12, 9, 5, 7, 11, 52, 38, 34, 33, 40, 18, 13, 14, 17]]

# %% [markdown]
# # Plotando os mapas

# %% [markdown]
# ### Primeiro, vou montar o DF para consulta das lat, long

# %%
import geopandas as gpd
import pandas as pd
from pyproj import Proj, transform
import folium
import requests
import json

niteroi = gpd.read_file(r'Limite_de_Bairros\Limite_de_Bairros.shp')

centroide = niteroi.geometry.centroid

# Criando um DF com os dados: nomes do bairros, coordenada X do centroide e coordenada Y do centroide
df_niteroi = pd.DataFrame(data=[niteroi['tx_nome'], centroide.x, centroide.y])

# Transpondo o DF para ser melhor visualizado
df_niteroi = df_niteroi.T

# Alterando o nome das colunas para o DF ficar melhor
df_niteroi.rename(columns={'tx_nome': 'Bairro', 'Unnamed 0': 'Coordenada X', 'Unnamed 1': 'Coordenada Y'}, inplace=True)

# Setando o index como a coluna do nome do bairro para ficar melhor de utilizar
df_niteroi = df_niteroi.set_index('Bairro')

# Pegando a lista de bairros
lista_bairros = df_niteroi.index.values.tolist()

# Definir o sistema de coordenadas de origem (UTM) e destino (latitude e longitude)
in_proj = Proj(proj='utm', zone=23, south=True, ellps='WGS84')  # Zona UTM 23S para Niterói
out_proj = Proj(proj='latlong', ellps='WGS84')

# Lista com as latitudes
lista_latitudes = []
# Lista com as longitudes
lista_longitudes = []

# loop para todos bairros
for bairro in lista_bairros:
    centroide_x = df_niteroi['Coordenada X'][bairro]
    centroide_y = df_niteroi['Coordenada Y'][bairro]
    longitude, latitude = transform(in_proj, out_proj, centroide_x, centroide_y)
    lista_latitudes.append(latitude)
    lista_longitudes.append(longitude)

# Adicionando as listas no DF
df_niteroi['Latitude'] = lista_latitudes
df_niteroi['Longitude'] = lista_longitudes

# Adicionando os lockers

dic_lck = {
    'LCK Locker Niterói': [0, 0, -22.895003479257202, -43.123676732116806],
    'LCK Locker Plaza Niterói': [0, 0, -22.89685736201976, -43.12368572236378],
    'LCK Locker Ibiza Central Shopping': [0, 0, -22.934797810452835, -43.022309860219984],
    'LCK Locker MultiCenter Itaipu': [0, 0, -22.950992190154313, -43.029263021257925],
    'LCK Locker Rede Economia Largo da Batalha': [0, 0, -22.90201224264317, -43.063982861147544]
}

df_lck = pd.DataFrame(dic_lck)

dic_cdds = {
    'CDD Niterói': [0, 0, -22.887424942376885, -43.12354567072342],
    'CDD Itaipu': [0, 0, -22.941380166125, -43.05286546954709],
    'CDD Icaraí': [0, 0, -22.895901773417418, -43.10074638349823],
    'CDD Largo da batalha': [0, 0, -22.90626685913838, -43.05616179121699]
}

df_cdds = pd.DataFrame(dic_cdds)

df_lck = df_lck.T.rename(columns={0:'Coordenada X', 1: 'Coordenada Y', 2:'Latitude', 3:'Longitude'})

df_cdds = df_cdds.T.rename(columns={0:'Coordenada X', 1: 'Coordenada Y', 2:'Latitude', 3:'Longitude'})

df_completo = pd.concat([df_niteroi, df_lck, df_cdds])

df_completo
# Out:
# C:\Users\Felipe\AppData\Local\Temp\ipykernel_94972\1473237076.py:40: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   longitude, latitude = transform(in_proj, out_proj, centroide_x, centroide_y)
#                                             Coordenada X    Coordenada Y  \
# Varzea das Moças                            707475.54785  7464536.556436
# Muriqui                                    702741.639181  7466123.050743
# Rio do Ouro                                704887.923636   7465784.17919
# Serra Grande                               703525.846044  7463340.190273
# Cafubá                                     698219.267314   7463354.25775
# ...                                                  ...             ...
# LCK Locker Rede Economia Largo da Batalha            0.0             0.0
# CDD Niterói                                          0.0             0.0
# CDD Itaipu                                           0.0             0.0
# CDD Icaraí                                           0.0             0.0
# CDD Largo da batalha                                 0.0             0.0
#
#                                             Latitude  Longitude
# Varzea das Moças                          -22.914337 -42.977053
# Muriqui                                   -22.900595 -43.023396
# Rio do Ouro                               -22.903393 -43.002436
# Serra Grande                              -22.925624 -43.015388
# Cafubá                                    -22.926135 -43.067112
# ...                                              ...        ...
# LCK Locker Rede Economia Largo da Batalha -22.902012 -43.063983
# CDD Niterói                               -22.887425 -43.123546
# CDD Itaipu                                -22.941380 -43.052865
# CDD Icaraí                                -22.895902 -43.100746
# CDD Largo da batalha                      -22.906267 -43.056162
#
# [61 rows x 4 columns]

# %% [markdown]
# ### Lista das rotas que são o resultado do problema

# %%
lista_rotas_01 = [df01.iloc[a].name for a in result_01.routes[0]]
lista_rotas_02 = [df02.iloc[a].name for a in result_02.routes[0]]
lista_rotas_03 = [df03.iloc[a].name for a in result_03.routes[0]]
lista_rotas_04 = [df04.iloc[a].name for a in result_04.routes[0]]

# %% [markdown]
# ### No resultado direto do modelo, não tem o "depot", logo tenho que adicionar ele manualmente na primeira posição, pois as entregas sempre partem de lá

# %%
# Cenário 01 - CDD Niterói
lista_rotas_01.insert(0, 'CDD Niterói')
# Cenário 02 - CDD Itaipu
lista_rotas_02.insert(0, 'CDD Itaipu')
# Cenário 03 - CDD Icaraí
lista_rotas_03.insert(0, 'CDD Icaraí')
# Cenário 04 - CDD Largo da batalha
lista_rotas_04.insert(0, 'CDD Largo da batalha')

# %% [markdown]
# ### Lista das coordenadas para plotar

# %%
lista_coordenadas_01 = [[df_completo.loc[a]['Latitude'], df_completo.loc[a]['Longitude']] for a in lista_rotas_01]
lista_coordenadas_02 = [[df_completo.loc[a]['Latitude'], df_completo.loc[a]['Longitude']] for a in lista_rotas_02]
lista_coordenadas_03 = [[df_completo.loc[a]['Latitude'], df_completo.loc[a]['Longitude']] for a in lista_rotas_03]
lista_coordenadas_04 = [[df_completo.loc[a]['Latitude'], df_completo.loc[a]['Longitude']] for a in lista_rotas_04]

# %% [markdown]
# ## Cenário 01

# %%
mapa01 = folium.Map(location = [-22.918769490782978, -43.056979733841224], zoom_start = 13, width = 1500, height = 1000, control_scale = True)

# Pegando a lista completa de bairros/lockers/cdds
lista_01 = df01.index.values.tolist()

for bairro in lista_01:
    if bairro.split()[0] == 'LCK':
        folium.Marker(location = [df_completo['Latitude'][bairro], df_completo['Longitude'][bairro]],
                    tooltip = bairro, 
                    icon = folium.Icon(color = 'red'),).add_to(mapa01)
    elif bairro.split()[0] == 'CDD':
        folium.Marker(location = [df_completo['Latitude'][bairro], df_completo['Longitude'][bairro]],
                    tooltip = bairro, 
                    icon = folium.Icon(color = 'green'),).add_to(mapa01)
    else:
        folium.Marker(location = [df_completo['Latitude'][bairro], df_completo['Longitude'][bairro]],
                    tooltip = bairro, 
                    icon = folium.Icon(color = 'black'),).add_to(mapa01)

# Plotando a linha da melhor rota

folium.PolyLine(
    locations=lista_coordenadas_01,
    color="#FF0000",
    weight=3,
    tooltip="Melhor rota para Cenário 01",
).add_to(mapa01)

mapa01
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_80a0538f5501422a04c6937a53a688ea {
#                     position: relative;
#                     width: 1500.0px;
#                     height: 1000.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_80a0538f5501422a04c6937a53a688ea&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_80a0538f5501422a04c6937a53a688ea = L.map(
#                 &quot;map_80a0538f5501422a04c6937a53a688ea&quot;,
#                 {
#                     center: [-22.918769490782978, -43.056979733841224],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_80a0538f5501422a04c6937a53a688ea);
#
#
#
#
#
#             var tile_layer_e7f674caf1676e2409ff9af78d62c12b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e7f674caf1676e2409ff9af78d62c12b.addTo(map_80a0538f5501422a04c6937a53a688ea);
#
#
#             var marker_81eac93d977ecf01f659066742064876 = L.marker(
#                 [-22.887424942376885, -43.12354567072342],
#                 {}
#             ).addTo(map_80a0538f5501422a04c6937a53a688ea);
#
#
#             var icon_e61bda2c2689acb3d19ca2fb6adee360 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_81eac93d977ecf01f659066742064876.setIcon(icon_e61bda2c2689acb3d19ca2fb6adee360);
#
#
#             marker_81eac93d977ecf01f659066742064876.bindTooltip(
#                 `&lt;div&gt;
#                      CDD Niterói
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_16aa397cb7812dbba08075ac66e625b7 = L.marker(
#                 [-22.9143371189906, -42.97705285003985],
#                 {}
#             ).addTo(map_80a0538f5501422a04c6937a53a688ea);
#
#
#             var icon_5af2864ab0f5a2a58f9e1cc9ca01c3d0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_16aa397cb7812dbba08075ac66e625b7.setIcon(icon_5af2864ab0f5a2a58f9e1cc9ca01c3d0);
#
#
#             marker_16aa397cb7812dbba08075ac66e625b7.bindTooltip(
#                 `&lt;div&gt;
#                      Varzea das Moças
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_275fc87c065b183051de9109389059f7 = L.marker(
#                 [-22.900595071837806, -43.0233961250927],
#                 {}
#             ).addTo(map_80a0538f5501422a04c6937a53a688ea);
#
#
#             var icon_9c809f80fe99be00f71dc21e3d6e491f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_275fc87c065b183051de9109389059f7.setIcon(icon_9c809f80fe99be00f71dc21e3d6e491f);
#
#
#             marker_275fc87c065b183051de9109389059f7.bindTooltip(
#                 `&lt;div&gt;
#                      Muriqui
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_2f844810c1016b9a7d0f6fb3c79394d6 = L.marker(
#                 [-22.903392814093046, -43.00243612743767],
#                 {}
#             ).addTo(map_80a0538f5501422a04c6937a53a688ea);
#
#
#             var icon_8fbc2cb322f38a6e45576a942e84b3d8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2f844810c1016b9a7d0f6fb3c79394d6.setIcon(icon_8fbc2cb322f38a6e45576a942e84b3d8);
#
#
#             marker_2f844810c1016b9a7d0f6fb3c79394d6.bindTooltip(
#                 `&lt;div&gt;
#                      Rio do Ouro
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_0d3b8e2306a3af9e29ab9eb696743338 = L.marker(
#                 [-22.925623754711445, -43.015388264802276],
#                 {}
#             ).addTo(map_80a0538f5501422a04c6937a53a688ea);
#
#
#             var icon_1014028f3694a9d3e9f8c87462a1b3fb = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quo

# %% [markdown]
# ## Cenário 02

# %%
mapa03 = folium.Map(location = [-22.918769490782978, -43.056979733841224], zoom_start = 13, width = 1500, height = 1000, control_scale = True)

# Pegando a lista completa de bairros/lockers/cdds
lista_02 = df02.index.values.tolist()

for bairro in lista_02:
    if bairro.split()[0] == 'LCK':
        folium.Marker(location = [df_completo['Latitude'][bairro], df_completo['Longitude'][bairro]],
                    tooltip = bairro, 
                    icon = folium.Icon(color = 'red'),).add_to(mapa02)
    elif bairro.split()[0] == 'CDD':
        folium.Marker(location = [df_completo['Latitude'][bairro], df_completo['Longitude'][bairro]],
                    tooltip = bairro, 
                    icon = folium.Icon(color = 'green'),).add_to(mapa02)
    else:
        folium.Marker(location = [df_completo['Latitude'][bairro], df_completo['Longitude'][bairro]],
                    tooltip = bairro, 
                    icon = folium.Icon(color = 'black'),).add_to(mapa02)

# Plotando a linha da melhor rota

folium.PolyLine(
    locations=lista_coordenadas_02,
    color="#FF0000",
    weight=3,
    tooltip="Melhor rota para Cenário 02",
).add_to(mapa02)

mapa02
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_572efd6a75c6f0c4f7493a40cbd254e0 {
#                     position: relative;
#                     width: 1500.0px;
#                     height: 1000.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_572efd6a75c6f0c4f7493a40cbd254e0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_572efd6a75c6f0c4f7493a40cbd254e0 = L.map(
#                 &quot;map_572efd6a75c6f0c4f7493a40cbd254e0&quot;,
#                 {
#                     center: [-22.918769490782978, -43.056979733841224],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_572efd6a75c6f0c4f7493a40cbd254e0);
#
#
#
#
#
#             var tile_layer_837e55e908fb785074ee9abc625a58de = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_837e55e908fb785074ee9abc625a58de.addTo(map_572efd6a75c6f0c4f7493a40cbd254e0);
#
#
#             var marker_afc9b6bf964d4baeb1698840d537e0fa = L.marker(
#                 [-22.941380166125, -43.05286546954709],
#                 {}
#             ).addTo(map_572efd6a75c6f0c4f7493a40cbd254e0);
#
#
#             var icon_e9cd567f35871720a050ccc6da837853 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_afc9b6bf964d4baeb1698840d537e0fa.setIcon(icon_e9cd567f35871720a050ccc6da837853);
#
#
#             marker_afc9b6bf964d4baeb1698840d537e0fa.bindTooltip(
#                 `&lt;div&gt;
#                      CDD Itaipu
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_2cdcb881e7d03161f80184f1aff36717 = L.marker(
#                 [-22.9143371189906, -42.97705285003985],
#                 {}
#             ).addTo(map_572efd6a75c6f0c4f7493a40cbd254e0);
#
#
#             var icon_56690d19728ed05cbe0be73d31492cf2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2cdcb881e7d03161f80184f1aff36717.setIcon(icon_56690d19728ed05cbe0be73d31492cf2);
#
#
#             marker_2cdcb881e7d03161f80184f1aff36717.bindTooltip(
#                 `&lt;div&gt;
#                      Varzea das Moças
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_4ec312a879a1780972e425ee34fa34b4 = L.marker(
#                 [-22.900595071837806, -43.0233961250927],
#                 {}
#             ).addTo(map_572efd6a75c6f0c4f7493a40cbd254e0);
#
#
#             var icon_5cda1d090e9061a0e71c9b51abe35737 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4ec312a879a1780972e425ee34fa34b4.setIcon(icon_5cda1d090e9061a0e71c9b51abe35737);
#
#
#             marker_4ec312a879a1780972e425ee34fa34b4.bindTooltip(
#                 `&lt;div&gt;
#                      Muriqui
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5b224092d27adb98fb11f21cf1bac7ba = L.marker(
#                 [-22.903392814093046, -43.00243612743767],
#                 {}
#             ).addTo(map_572efd6a75c6f0c4f7493a40cbd254e0);
#
#
#             var icon_52d8d760342b23dc74dfaa161e0b25af = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5b224092d27adb98fb11f21cf1bac7ba.setIcon(icon_52d8d760342b23dc74dfaa161e0b25af);
#
#
#             marker_5b224092d27adb98fb11f21cf1bac7ba.bindTooltip(
#                 `&lt;div&gt;
#                      Rio do Ouro
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_60d2bac8ecad248d056b0c30fab14380 = L.marker(
#                 [-22.925623754711445, -43.015388264802276],
#                 {}
#             ).addTo(map_572efd6a75c6f0c4f7493a40cbd254e0);
#
#
#             var icon_6710f71bff7765a27b65531b7aa1927a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;:

# %% [markdown]
# ## Cenário 03

# %%
mapa03 = folium.Map(location = [-22.918769490782978, -43.056979733841224], zoom_start = 13, width = 1500, height = 1000, control_scale = True)

# Pegando a lista completa de bairros/lockers/cdds
lista_03 = df03.index.values.tolist()

for bairro in lista_03:
    if bairro.split()[0] == 'LCK':
        folium.Marker(location = [df_completo['Latitude'][bairro], df_completo['Longitude'][bairro]],
                    tooltip = bairro, 
                    icon = folium.Icon(color = 'red'),).add_to(mapa03)
    elif bairro.split()[0] == 'CDD':
        folium.Marker(location = [df_completo['Latitude'][bairro], df_completo['Longitude'][bairro]],
                    tooltip = bairro, 
                    icon = folium.Icon(color = 'green'),).add_to(mapa03)
    else:
        folium.Marker(location = [df_completo['Latitude'][bairro], df_completo['Longitude'][bairro]],
                    tooltip = bairro, 
                    icon = folium.Icon(color = 'black'),).add_to(mapa03)

# Plotando a linha da melhor rota

folium.PolyLine(
    locations=lista_coordenadas_03,
    color="#FF0000",
    weight=3,
    tooltip="Melhor rota para Cenário 03",
).add_to(mapa03)

mapa03
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a8b0170d1f9e2bfbefe332d596ac086f {
#                     position: relative;
#                     width: 1500.0px;
#                     height: 1000.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a8b0170d1f9e2bfbefe332d596ac086f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a8b0170d1f9e2bfbefe332d596ac086f = L.map(
#                 &quot;map_a8b0170d1f9e2bfbefe332d596ac086f&quot;,
#                 {
#                     center: [-22.918769490782978, -43.056979733841224],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_a8b0170d1f9e2bfbefe332d596ac086f);
#
#
#
#
#
#             var tile_layer_32d589d0f6f149a4a4f1758777cfb1ff = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_32d589d0f6f149a4a4f1758777cfb1ff.addTo(map_a8b0170d1f9e2bfbefe332d596ac086f);
#
#
#             var marker_ba1dfb522d064f5bfc14a03a36afa347 = L.marker(
#                 [-22.895901773417418, -43.10074638349823],
#                 {}
#             ).addTo(map_a8b0170d1f9e2bfbefe332d596ac086f);
#
#
#             var icon_22eee41939426d85feacc1ccc7719f51 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ba1dfb522d064f5bfc14a03a36afa347.setIcon(icon_22eee41939426d85feacc1ccc7719f51);
#
#
#             marker_ba1dfb522d064f5bfc14a03a36afa347.bindTooltip(
#                 `&lt;div&gt;
#                      CDD Icaraí
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_eb692c2a40db5a8df0177134370c0e2f = L.marker(
#                 [-22.9143371189906, -42.97705285003985],
#                 {}
#             ).addTo(map_a8b0170d1f9e2bfbefe332d596ac086f);
#
#
#             var icon_7f71b7034938d70a7e71b430bcf3302a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_eb692c2a40db5a8df0177134370c0e2f.setIcon(icon_7f71b7034938d70a7e71b430bcf3302a);
#
#
#             marker_eb692c2a40db5a8df0177134370c0e2f.bindTooltip(
#                 `&lt;div&gt;
#                      Varzea das Moças
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_68e1a14b7b7f9dfcc440422fcabfbe9b = L.marker(
#                 [-22.900595071837806, -43.0233961250927],
#                 {}
#             ).addTo(map_a8b0170d1f9e2bfbefe332d596ac086f);
#
#
#             var icon_3c7ceaa69d67f01231d5713fa15593b6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_68e1a14b7b7f9dfcc440422fcabfbe9b.setIcon(icon_3c7ceaa69d67f01231d5713fa15593b6);
#
#
#             marker_68e1a14b7b7f9dfcc440422fcabfbe9b.bindTooltip(
#                 `&lt;div&gt;
#                      Muriqui
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_1f4c02eb44dbb484fff4a1e15e1dbe84 = L.marker(
#                 [-22.903392814093046, -43.00243612743767],
#                 {}
#             ).addTo(map_a8b0170d1f9e2bfbefe332d596ac086f);
#
#
#             var icon_7aaff90defcfb93f3e131f9a136c6f86 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1f4c02eb44dbb484fff4a1e15e1dbe84.setIcon(icon_7aaff90defcfb93f3e131f9a136c6f86);
#
#
#             marker_1f4c02eb44dbb484fff4a1e15e1dbe84.bindTooltip(
#                 `&lt;div&gt;
#                      Rio do Ouro
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_707c1bd2b2523484e30a6889c078f9bb = L.marker(
#                 [-22.925623754711445, -43.015388264802276],
#                 {}
#             ).addTo(map_a8b0170d1f9e2bfbefe332d596ac086f);
#
#
#             var icon_a463651acdce380b623908c83b699022 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot

# %% [markdown]
# ## Cenário 04

# %%
mapa04 = folium.Map(location = [-22.918769490782978, -43.056979733841224], zoom_start = 13, width = 1500, height = 1000, control_scale = True)

# Pegando a lista completa de bairros/lockers/cdds
lista_04 = df04.index.values.tolist()

for bairro in lista_04:
    if bairro.split()[0] == 'LCK':
        folium.Marker(location = [df_completo['Latitude'][bairro], df_completo['Longitude'][bairro]],
                    tooltip = bairro, 
                    icon = folium.Icon(color = 'red'),).add_to(mapa04)
    elif bairro.split()[0] == 'CDD':
        folium.Marker(location = [df_completo['Latitude'][bairro], df_completo['Longitude'][bairro]],
                    tooltip = bairro, 
                    icon = folium.Icon(color = 'green'),).add_to(mapa04)
    else:
        folium.Marker(location = [df_completo['Latitude'][bairro], df_completo['Longitude'][bairro]],
                    tooltip = bairro, 
                    icon = folium.Icon(color = 'black'),).add_to(mapa04)

# Plotando a linha da melhor rota

folium.PolyLine(
    locations=lista_coordenadas_04,
    color="#FF0000",
    weight=3,
    tooltip="Melhor rota para Cenário 04",
).add_to(mapa04)

mapa04
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_484313a5e89d2f0eb150923fc360c753 {
#                     position: relative;
#                     width: 1500.0px;
#                     height: 1000.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_484313a5e89d2f0eb150923fc360c753&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_484313a5e89d2f0eb150923fc360c753 = L.map(
#                 &quot;map_484313a5e89d2f0eb150923fc360c753&quot;,
#                 {
#                     center: [-22.918769490782978, -43.056979733841224],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_484313a5e89d2f0eb150923fc360c753);
#
#
#
#
#
#             var tile_layer_d251c88fd4e00ff10d9ebba3ea913d76 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d251c88fd4e00ff10d9ebba3ea913d76.addTo(map_484313a5e89d2f0eb150923fc360c753);
#
#
#             var marker_9cfd7c7e554c7b8cb1369756d07eeb8f = L.marker(
#                 [-22.90626685913838, -43.05616179121699],
#                 {}
#             ).addTo(map_484313a5e89d2f0eb150923fc360c753);
#
#
#             var icon_bc2065b4eaeae7b8f47d9cba0713f171 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9cfd7c7e554c7b8cb1369756d07eeb8f.setIcon(icon_bc2065b4eaeae7b8f47d9cba0713f171);
#
#
#             marker_9cfd7c7e554c7b8cb1369756d07eeb8f.bindTooltip(
#                 `&lt;div&gt;
#                      CDD Largo da batalha
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_7f66bcc23ff42c60757464f06b60ac4e = L.marker(
#                 [-22.9143371189906, -42.97705285003985],
#                 {}
#             ).addTo(map_484313a5e89d2f0eb150923fc360c753);
#
#
#             var icon_f3103e891257d05ee1dfac887ecfdc5c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7f66bcc23ff42c60757464f06b60ac4e.setIcon(icon_f3103e891257d05ee1dfac887ecfdc5c);
#
#
#             marker_7f66bcc23ff42c60757464f06b60ac4e.bindTooltip(
#                 `&lt;div&gt;
#                      Varzea das Moças
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_87f4437f7163042416bbe57c3f518e33 = L.marker(
#                 [-22.900595071837806, -43.0233961250927],
#                 {}
#             ).addTo(map_484313a5e89d2f0eb150923fc360c753);
#
#
#             var icon_a5b298e62da85d79228536134c342566 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_87f4437f7163042416bbe57c3f518e33.setIcon(icon_a5b298e62da85d79228536134c342566);
#
#
#             marker_87f4437f7163042416bbe57c3f518e33.bindTooltip(
#                 `&lt;div&gt;
#                      Muriqui
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_0856458b3a786ae7ac53dee8d7d390f5 = L.marker(
#                 [-22.903392814093046, -43.00243612743767],
#                 {}
#             ).addTo(map_484313a5e89d2f0eb150923fc360c753);
#
#
#             var icon_5ee513095adec7adc48e862b79b11ee5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0856458b3a786ae7ac53dee8d7d390f5.setIcon(icon_5ee513095adec7adc48e862b79b11ee5);
#
#
#             marker_0856458b3a786ae7ac53dee8d7d390f5.bindTooltip(
#                 `&lt;div&gt;
#                      Rio do Ouro
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_20d88a0182fa35e5e0212c75f0084fb3 = L.marker(
#                 [-22.925623754711445, -43.015388264802276],
#                 {}
#             ).addTo(map_484313a5e89d2f0eb150923fc360c753);
#
#
#             var icon_41740b8bf850a4e71f28ef311ba110d9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerC

# %%
# Só pensar numa maneira de colocar uma linha ligando o último ponto com o primeiro, pq ele volta pro depot
